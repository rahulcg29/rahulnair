# %%
import matplotlib.pyplot as plt

def get_runs():
    runs = []
    for over in range(1, 11):
        run = int(input(f"Enter runs scored in over {over}: "))
        runs.append(run)
    return runs
    
def plot_runs(runs):
    overs = [f"Over {i}" for i in range(1, 11)]
    plt.figure(figsize=(10, 6))
    plt.bar(overs, runs, color='skyblue', edgecolor='black')
    plt.title("Runs Scored per Over in Cricket Match")
    plt.xlabel("Overs")
    plt.ylabel("Runs")
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()
runs = get_runs()
plot_runs(runs)
# Out:
# Enter runs scored in over 1:  10
# Enter runs scored in over 2:  20
# Enter runs scored in over 3:  20
# Enter runs scored in over 4:  50
# Enter runs scored in over 5:  60
# Enter runs scored in over 6:  70
# Enter runs scored in over 7:  80
# Enter runs scored in over 8:  90
# Enter runs scored in over 9:  85
# Enter runs scored in over 10:  75

# %%
import matplotlib.pyplot as plt

def get_wicket_data():
    wickets = []
    print("Enter number of wickets fallen in each over (0 to 10 overs):")
    for i in range(1, 11):
        while True:
            try:
                wkts = int(input(f"Over {i}: "))
                if 0 <= wkts <= 10:
                    wickets.append(wkts)
                    break
                else:
                    print("Wickets must be between 0 and 10.")
            except ValueError:
                print("Invalid input. Please enter an integer.")
    return wickets
def plot_wickets(wickets):
    overs = [f"Over {i}" for i in range(1, 11)]
    plt.figure(figsize=(10, 6))
    plt.bar(overs, wickets, color='green', edgecolor='black')
    plt.title("Fall of Wickets per Over")
    plt.xlabel("Overs")
    plt.ylabel("Number of Wickets")
    plt.ylim(0, max(wickets) + 1)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()
wicket_data = get_wicket_data()
plot_wickets(wicket_data)
# Out:
# Enter number of wickets fallen in each over (0 to 10 overs):
# Over 1:  4
# Over 2:  7
# Over 3:  8
# Over 4:  9
# Over 5:  1
# Over 6:  2
# Over 7:  8
# Over 8:  7
# Over 9:  9
# Over 10:  10
